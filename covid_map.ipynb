# %% [markdown]
# # <center>World Map Geovisualization using Folium and Covid Data

# %% [markdown]
# ### Import Libraries

# %%
import json
import folium
import requests
import mimetypes
import http.client
import pandas as pd
from folium.plugins import HeatMap
from pandas.io.json import json_normalize

# %% [markdown]
# ### Access Data via API

# %%
conn=http.client.HTTPSConnection("api.covid19api.com")
payload=''
headers={}
conn.request("GET","/summary",payload,headers)
res=conn.getresponse()
data=res.read().decode('UTF-8')

# %% [markdown]
# ### Convert Data to JSON

# %%
covid1=json.loads(data)

# %% [markdown]
# ### Normalize Data

# %%
pd.json_normalize(covid1['Countries'],sep=",")
# Out:
#                                        ID                          Country  \
# 0    0e3ca669-19a0-46c7-8612-f031323181ca                      Afghanistan
# 1    7611eb38-4043-4d38-9516-109a809eefea                          Albania
# 2    4c6f1270-8638-4670-8979-4cc2fcf4dc80                          Algeria
# 3    50cdd3b5-a687-446f-ac31-725ce22251f7                          Andorra
# 4    e195382e-753f-41b7-b7a3-38f5b969348a                           Angola
# ..                                    ...                              ...
# 185  328861bc-4da1-4760-9bb1-5e0d85399c47  Venezuela (Bolivarian Republic)
# 186  87296481-8456-49db-8791-6cff81718080                         Viet Nam
# 187  4da25b53-312b-4eee-b7c5-99bd895f4f0a                            Yemen
# 188  ba77f002-a7bb-4b44-a8ff-5e0d44324d95                           Zambia
# 189  529f6175-feec-43f5-8abf-d47868c973e2                         Zimbabwe
#
#     CountryCode         Slug  NewConfirmed  TotalConfirmed  NewDeaths  \
# 0            AF  afghanistan           194           59939          6
# 1            AL      albania           100          131185          2
# 2            DZ      algeria           203          122311          8
# 3            AD      andorra             0           13232          0
# 4            AO       angola             0           26652          0
# ..          ...          ...           ...             ...        ...
# 185          VE    venezuela             0          197683          0
# 186          VN      vietnam            14            2942          0
# 187          YE        yemen             8            6325          3
# 188          ZM       zambia            84           91670          0
# 189          ZW     zimbabwe             3           38260          1
#
#      TotalDeaths  NewRecovered  TotalRecovered                      Date
# 0           2631            66           53272  2021-05-02T04:54:10.678Z
# 1           2396           834          110172  2021-05-02T04:54:10.678Z
# 2           3261           141           85249  2021-05-02T04:54:10.678Z
# 3            125             0           12684  2021-05-02T04:54:10.678Z
# 4            596             0           23876  2021-05-02T04:54:10.678Z
# ..           ...           ...             ...                       ...
# 185         2136             0          179200  2021-05-02T04:54:10.678Z
# 186           35            32            2548  2021-05-02T04:54:10.678Z
# 187         1229            43            2794  2021-05-02T04:54:10.678Z
# 188         1251            79           90012  2021-05-02T04:54:10.678Z
# 189         1568             8           35620  2021-05-02T04:54:10.678Z
#
# [190 rows x 11 columns]

# %% [markdown]
# ### Convert to Pandas DataFrame

# %%
df=pd.DataFrame(covid1['Countries'])
df
# Out:
#                                        ID                          Country  \
# 0    0e3ca669-19a0-46c7-8612-f031323181ca                      Afghanistan
# 1    7611eb38-4043-4d38-9516-109a809eefea                          Albania
# 2    4c6f1270-8638-4670-8979-4cc2fcf4dc80                          Algeria
# 3    50cdd3b5-a687-446f-ac31-725ce22251f7                          Andorra
# 4    e195382e-753f-41b7-b7a3-38f5b969348a                           Angola
# ..                                    ...                              ...
# 185  328861bc-4da1-4760-9bb1-5e0d85399c47  Venezuela (Bolivarian Republic)
# 186  87296481-8456-49db-8791-6cff81718080                         Viet Nam
# 187  4da25b53-312b-4eee-b7c5-99bd895f4f0a                            Yemen
# 188  ba77f002-a7bb-4b44-a8ff-5e0d44324d95                           Zambia
# 189  529f6175-feec-43f5-8abf-d47868c973e2                         Zimbabwe
#
#     CountryCode         Slug  NewConfirmed  TotalConfirmed  NewDeaths  \
# 0            AF  afghanistan           194           59939          6
# 1            AL      albania           100          131185          2
# 2            DZ      algeria           203          122311          8
# 3            AD      andorra             0           13232          0
# 4            AO       angola             0           26652          0
# ..          ...          ...           ...             ...        ...
# 185          VE    venezuela             0          197683          0
# 186          VN      vietnam            14            2942          0
# 187          YE        yemen             8            6325          3
# 188          ZM       zambia            84           91670          0
# 189          ZW     zimbabwe             3           38260          1
#
#      TotalDeaths  NewRecovered  TotalRecovered                      Date  \
# 0           2631            66           53272  2021-05-02T04:54:10.678Z
# 1           2396           834          110172  2021-05-02T04:54:10.678Z
# 2           3261           141           85249  2021-05-02T04:54:10.678Z
# 3            125             0           12684  2021-05-02T04:54:10.678Z
# 4            596             0           23876  2021-05-02T04:54:10.678Z
# ..           ...           ...             ...                       ...
# 185         2136             0          179200  2021-05-02T04:54:10.678Z
# 186           35            32            2548  2021-05-02T04:54:10.678Z
# 187         1229            43            2794  2021-05-02T04:54:10.678Z
# 188         1251            79           90012  2021-05-02T04:54:10.678Z
# 189         1568             8           35620  2021-05-02T04:54:10.678Z
#
#     Premium
# 0        {}
# 1        {}
# 2        {}
# 3        {}
# 4        {}
# ..      ...
# 185      {}
# 186      {}
# 187      {}
# 188      {}
# 189      {}
#
# [190 rows x 12 columns]

# %% [markdown]
# ### Drop Unnecessary Columns

# %%
covid2=df.drop(columns=['ID','CountryCode','Slug','Date','Premium'],axis=1)
covid2
# Out:
#                              Country  NewConfirmed  TotalConfirmed  NewDeaths  \
# 0                        Afghanistan           194           59939          6
# 1                            Albania           100          131185          2
# 2                            Algeria           203          122311          8
# 3                            Andorra             0           13232          0
# 4                             Angola             0           26652          0
# ..                               ...           ...             ...        ...
# 185  Venezuela (Bolivarian Republic)             0          197683          0
# 186                         Viet Nam            14            2942          0
# 187                            Yemen             8            6325          3
# 188                           Zambia            84           91670          0
# 189                         Zimbabwe             3           38260          1
#
#      TotalDeaths  NewRecovered  TotalRecovered
# 0           2631            66           53272
# 1           2396           834          110172
# 2           3261           141           85249
# 3            125             0           12684
# 4            596             0           23876
# ..           ...           ...             ...
# 185         2136             0          179200
# 186           35            32            2548
# 187         1229            43            2794
# 188         1251            79           90012
# 189         1568             8           35620
#
# [190 rows x 7 columns]

# %% [markdown]
# ### Generate Base Map

# %%
m=folium.Map(tiles="Stamen Terrain",min_zoom=1.5)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Obtain Geodata
#
# geodata url: https://raw.githubusercontent.com/python-visualization/folium/master/examples/data
#
# geo data file: world-countries.json

# %%
url='https://raw.githubusercontent.com/python-visualization/folium/master/examples/data'
country_shapes= f'{url}/world-countries.json'

# %% [markdown]
# ### Generate Choropleth Map Layer

# %%
folium.Choropleth(
    geo_data=country_shapes,
    min_zoom=2,
    name='Covid-19',
    data=covid2,
    columns=['Country','TotalConfirmed'],
    key_on='feature.properties.name',
    fill_color='OrRd',
    nan_fill_color='black',
    legend_name='Total Confirmed Covid Cases',
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Generate Circular Markers

# %%
covid2.update(covid2['TotalConfirmed'].map('Total Confirmed:{}'.format))
covid2.update(covid2['TotalRecovered'].map('Total Recovered:{}'.format))

# %% [markdown]
# coordinates of countries: https://raw.githubusercontent.com/VinitaSilaparasetty/covid-map/master/country-coordinates-world.csv

# %%
coordinates=pd.read_csv('https://raw.githubusercontent.com/VinitaSilaparasetty/covid-map/master/country-coordinates-world.csv')
coordinates
# Out:
#       latitude   longitude            Country
# 0    33.939110   67.709953        Afghanistan
# 1    41.153332   20.168331            Albania
# 2    28.033886    1.659626            Algeria
# 3   -14.270972 -170.132217     American Samoa
# 4    42.546245    1.601554            Andorra
# ..         ...         ...                ...
# 239 -13.768752 -177.156097  Wallis and Futuna
# 240  24.215527  -12.885834     Western Sahara
# 241  15.552727   48.516388              Yemen
# 242 -13.133897   27.849332             Zambia
# 243 -19.015438   29.154857           Zimbabwe
#
# [244 rows x 3 columns]

# %%
covid_final=pd.merge(covid2,coordinates,on='Country')

# %%
def plotDot(point):
    folium.CircleMarker(location=[point.latitude,point.longitude],
                       radius=5,
                       weight=2,
                       popup=[point.Country,point.TotalConfirmed,point.TotalRecovered],
                       fill_color='#000000').add_to(m)

# %%
covid_final.apply(plotDot,axis=1)
m.fit_bounds(m.get_bounds())
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Generate Base Map

# %%
m1= folium.Map(tiles='StamenToner',min_zoom=2)

m1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
deaths=covid_final['TotalDeaths'].astype(float)

# %%
lat=covid_final['latitude'].astype(float)

# %%
lon=covid_final['longitude'].astype(float)

# %% [markdown]
# ### Generate Heat Map Layer

# %%
m1.add_child(HeatMap(zip(lat,lon,deaths),radius=0))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Generate Circular Marker

# %%
def plotDot(point):
    folium.CircleMarker(location=[point.latitude,point.longitude],
                       radius=5,
                       weight=2,
                       popup=[point.Country,point.TotalConfirmed,point.TotalRecovered],
                       fill_color='#000000').add_to(m1)

# %%
covid_final.apply(plotDot,axis=1)

m1.fit_bounds(m1.get_bounds())

m1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
