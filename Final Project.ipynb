# %% [markdown]
# # Capstone Project-The Battle Of Neighborhoods

# %% [markdown]
# #####   Part 1- A description of the problem and a discussion of the background.
# #####   Part 2 - A description of the data and how it will be used to solve the problem.

# %% [markdown]
# # Part 1

# %% [markdown]
# ## Introduction/Business Problem

# %% [markdown]
# ### •Toronto and New York being the financial capital of Canada and the US respectively are one of the densely populated cities in the world. Both these cities see a lot of diversity resulting from the movement of a lot of immigrants from several parts of the world for work and settlement. These are one of the most immigrant-friendly cities, still different in so many aspects, which we are going to observe in this work.

# %% [markdown]
# ### •This project will analyze neighborhoods between Toronto and New York City, New York. A company is looking to move its headquarters to either Toronto or New York City. The company wants insight into the neighborhoods and local businesses in the cities so that its employees may have the optimum living standards and quality of life. This project will explore the similarities and dissimilarities between certain neighborhoods in the two cities, and determine which neighborhoods best fit the culture of the  company’s employees.

# %% [markdown]
# ### •	Hence the problem is how to determine the right neighbourhood for company to set up its headquarter.

# %% [markdown]
# # Part 2

# %% [markdown]
# ## *Description of the data*

# %% [markdown]
# ### •The data used for this project will be acquired from the respective wikipedia website pages.The dataset consist of postal codes,neighborhood names,latittude and longitude information for each neighborhood.Foursquare API search feature will be used to collect neighborhood venue information.Details about local venues and locality will provide insight into the qualities of a neighborhood. In addition to Foursquare,various python packages will be used to create maps and machine learning models to further provide insights into our neighborhood battle project.

# %% [markdown]
# ### I used data from these websites
#  • Toronto Neighborhoods-https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M
#
#  • Toronto Latitude and Longtitude-http://cocl.us/Geospatial_data
#
#  • New York City Neighborhoods-https://geo.nyu.edu/catalog/nyu_2451_34572
#
#  • Foursquare database: https://Foursquare.com
